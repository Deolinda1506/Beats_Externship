# %% [markdown]
# <a href="https://colab.research.google.com/github/Deolinda1506/Beats_Externship/blob/main/Final_copy_of_Beats_by_Dre_Consumer_Insights_Capstone_Project_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project: Consumer Insights for Beats by Dre

# %% [markdown]
# Kindly use this template to get an overview of the structure that you need to follow in your capstone project.
#
# Ensure that the final insights that you produce in your analysis stand out and are easily accessible.
#
# You need to provide the code snippets that you used to run the code.

# %% [markdown]
# *italicized text*## 1. Title Page
# **Project Title:** Consumer Insights Data Analytics Externship of Beats by Dre
# **Student Name:** Gnon Deolinda Bio Bogore
#
# **Date:** 10/10/2024

# %% [markdown]
# ## 2. Table of Contents
# 1. Introduction
# 2. Data Description
# 3. Exploratory Data Analysis (EDA)
# 4. Sentiment Analysis
# 5. AI-Generated Insights
# 6. Comparative Analysis
# 7. Strategic Recommendations
# 8. Conclusion
# 9. References

# %% [markdown]
# ## 3. Introduction
#
# ### 3.1 Project Overview
# Briefly describe the purpose of the project and outline the key objectives.

# %% [markdown]
# This project aims to extract existing reviews of a Beats by Dre audio products from amazon and performing sentiment analysis and exploratory data analysis on the dataset. The data is compared to other reviews of similar audio products from different companies.
#
# **KEY OBJECTIVES:**
#
#
#
# *   Performed exploratory data analysis and data visualization of consumer reviews of Beats’ products and competitors.
# *   Used Python and data science libraries, including Pandas, Numpy, Seaborn, Matplotlib, NLTK, and Google Generative AI, to uncover patterns and trends in large datasets.
#
# *   Utilized advanced natural language processing tools, including Gemini AI, to interpret and summarize customer feedback.

# %% [markdown]
# ### 3.2 Background
# Provide context about Beats by Dre and the importance of consumer sentiment analysis in the tech industry.

# %% [markdown]
# ***ABOUT BEATS BY DRE:t***
#
# Beats by Dre is a prominent audio brand, co-founded by Dr. Dre and Jimmy Iovine in 2006. Known for its stylish design and powerful bass-heavy sound, the company has revolutionized the premium headphone market. In 2014, Beats by Dre was acquired by Apple Inc., further solidifying its place in the tech industry as a leader in audio technology and lifestyle products.
#
# **IMPORTANCE OF CONSUMER SENTIMENT ANALYSIS IN THE TECH INDUSTRY:**
#
# In the **competitive** tech industry, understanding consumer sentiment plays a critical role in:
#
#
#
#
#
#
#
# *   **Understanding Preferences**:Analyzing customer feedback helps reveal what consumers appreciate or dislike about products like Beats, providing valuable insight into user needs and preferences.
#
# *  **Improving Products** : Insights from sentiment analysis can help identify product issues and inform feature enhancements, leading to better user experiences and satisfaction.
#
# *   **Refining Marketing** : By understanding consumer sentiment, marketing messages can be tailored to emphasize product strengths and address consumer concerns, making campaigns more effective.
#
# *   **Managing Reputation** : Monitoring sentiment allows brands to amplify positive feedback and proactively respond to negative comments, protecting brand image and fostering trust.
#
#
#
# *  **Staying Competitive** : Tracking shifts in consumer sentiment helps companies adapt to evolving preferences, ensuring they stay ahead of competitors and remain relevant.
#
# *   **Guiding Decisions** :Consumer insights inform data-driven decisions for product development, pricing, and strategy, aligning with customer expectations and market demands.
#
# Consumer sentiment analysis empowers tech companies to better meet user expectations, optimize offerings, and secure a competitive edge.

# %% [markdown]
# ## 4. Data Description
#
# ### 4.1 Data Sources
# Describe the sources of your data (e.g., Amazon reviews).

# %% [markdown]
# **AMAZON REVIEWS:**
#
#
#
# *   The primary source of data for this project was customer reviews from Amazon.
#
# *  These reviews provided valuable insights into consumer opinions and experiences with various headphone products.
#
# **OXYLABS API:**
#
#
#
# *  Amazon reviews were collected using the Oxylabs API, which allowed for efficient and large-scale data gathering.
#
# *   The API provided access to detailed customer reviews, including ratings, review content, author information, and helpful counts, ensuring a comprehensive dataset for analysis.
#
# **Here are the headphone brands I've considered:**:
#
#
# 1MORE
#
# HTC
#
# JBL
#
# JLab
#
# Beats
#
# Jabra
#
# Sennheiser
#
# Skullcandy
#
# Sony
#
# Soundcore
#
# Bose

# %% [markdown]
# ### 4.2 Data Collection
# Explain the data gathering process, including any challenges faced and how they were overcome.

# %% [markdown]
# ##Data Gathering Process
#
# #Identifying Products:
#
# Beats Product: I started by selecting the Beats Pill Bluetooth Speaker, a popular product with substantial customer feedback on Amazon.
#
# Competitor Products: I identified similar Bluetooth speakers from brands like Bang & Olufsen Beoplay HX , Sony, JBL, and AKG, ensuring each had at least 100 reviews.
#
# Collecting URLs: I searched for the selected products on Amazon and copied the URLs of the product pages to gather the review data.
#
# ##Using Oxylabs API:
# Setup: I signed up for an Oxylabs account and used their eCommerce Scraper API to extract reviews. I set up the API to scrape reviews from the identified product pages.
#
# Parameters: I entered the ASIN (product identifier), selected user agent settings, and adjusted options to handle structured data.
#
# Testing and Adjustments: I tested the requests to ensure they were capturing the required data.
#
# ##Extracting Reviews:
# Initial Extraction: I used the API to extract up to 100 reviews per product. For products with more reviews, I adjusted page numbers and extraction settings to maximize data collection. Exporting Data: The data was exported as JSON files, which were then processed using Google Colab to convert them into a structured dataset.
#
# ##Compiling and Merging Data:
# Processing: I used a Google Colab notebook to parse the JSON data, load it into data frames, and save it as CSV files.
#
# Merging: The CSV files from different products were merged into a single dataset for comprehensive analysis.
#
# ##Challenges and Solutions
#
# **Data Extraction Limits**:
# Challenge: The Oxylabs API often limited review extraction to 100 reviews or 10 pages per product, which was less than the total number of reviews available.
#
# Solution: To overcome this, I focused on extracting reviews from multiple products to reach the total required amount. I also adjusted the number of pages in requests to gather as much data as possible.
#
#
# **Dynamic Content Handling**:
# Challenge: Amazon’s website content is dynamic, making it challenging to scrape data reliably.
#
# Solution: By using the Oxylabs API, which is designed to handle dynamic content, I avoided the complexities of building a custom scraper and ensured consistent data collection.
#
#
# **Data Processing**:
# Challenge: Converting JSON data into a structured dataset and merging multiple data sources required careful handling.
#
# Solution: I used the provided Google Colab notebook to automate the conversion and merging processes, ensuring data integrity and accuracy.

# %% [markdown]
# ### 4.3 Data Cleaning
# Outline the steps taken to clean and preprocess the data, highlighting any significant decisions made during this process.
#
# Load the data below and process cleaning here.

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()

df = pd.read_csv('updated_dataset.csv',index_col=0)

df.head()
# Out:
#      <input type="file" id="files-40a31a1e-fd78-4849-aaf4-68ed51588829" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40a31a1e-fd78-4849-aaf4-68ed51588829">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Checking for missing values in the dataset
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# review_id                0
# product_id               0
# title                    0
# author                   1
# rating                   0
# content                  8
# timestamp                0
# profile_id               0
# is_verified              0
# helpful_count            0
# product_attributes     224
# product_name          3763
# dtype: int64

# %% [markdown]
# It looks like the missing values are distributed across various columns, but the number of missing entries is relatively small.
#
# **Numerical column can't have a string datatype entry, So lets convert it to numeric**

# %%
# Convert the 'rating' column to numeric, coercing errors to NaN
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df['helpful_count'] = pd.to_numeric(df['helpful_count'], errors='coerce')
df['is_verified'] = pd.to_numeric(df['is_verified'], errors='coerce')

# %%
# Calculating the median of the 'rating' column after conversion
rating_median = df['rating'].median()
helpfulcount_median = df['helpful_count'].median()
verified_median = df['is_verified'].median()

# Fill missing 'rating' values with the median
df['rating'].fillna(rating_median, inplace=True)
df['helpful_count'].fillna(rating_median, inplace=True)
df['is_verified'].fillna(rating_median, inplace=True)
# Out:
# <ipython-input-5-df59fed329e2>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(rating_median, inplace=True)
# <ipython-input-5-df59fed329e2>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Drop Missing Values
#
# As the number of missing values is very small compared to the overall size of our dataset, and those rows aren't critical, we can drop them
#
# Drop Rows: As the missing data is less significant (like 1-3763 missing values in a dataset with thousands of rows), and those rows don't add much value, dropping them is generally safe.

# %%
# Drop rows with missing values in any column except 'rating'
df = df.dropna(subset=['review_id', 'product_id', 'title', 'author', 'content', 'timestamp', 'profile_id', 'product_attributes','product_name'])

# %%
# Crosschecking for missing values in the dataset
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# review_id             0
# product_id            0
# title                 0
# author                0
# rating                0
# content               0
# timestamp             0
# profile_id            0
# is_verified           0
# helpful_count         0
# product_attributes    0
# product_name          0
# dtype: int64

# %% [markdown]
# **Check for Duplicates**

# %%
# Check for duplicate rows
duplicates = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicates.shape[0]}")

# Drop duplicates
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# Handle Outliers
#
# Outliers can skew our analysis, so it’s important to identify and decide how to handle them.
#
# Using statistical methods like the Interquartile Range (IQR) or Z-scores for finding outliers.

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
print(numeric_cols)
# Out:
# Index(['rating', 'is_verified', 'helpful_count'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in numeric_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# **Remove Outliers**

# %%
Q1 = df['rating'].quantile(0.25)
Q3 = df['rating'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
df = df[(df['rating'] >= lower_bound) & (df['rating'] <= upper_bound)]

df = df[(df['is_verified'] != 0) & (df['is_verified'] != 5) & (df['helpful_count'] < 500)]

# %% [markdown]
# Here's a summary of what I have done:
#
# Filter Out Non-Verified Entries (is_verified):
#
# We're keeping only rows where is_verified is not 0 or 5, meaning we're focusing on entries that are more likely to be valid or trustworthy.
#
# Limit the helpful_count to Less Than 500:
#
# we're filtering out rows where helpful_count is 500 or more, keeping only those entries with a helpful_count of less than 500. This ensures we're working with reviews that are considered helpful but not excessively so, which could indicate manipulation or anomalies.
#
# **Checking the Impact of Outlier Handling**

# %%
import matplotlib.pyplot as plt # Import the matplotlib library
import seaborn as sns

for col in numeric_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col} After Outlier Handling')
    plt.show()

# %% [markdown]
# **Identify Categorical and Numerical Variables**

# %%
# List all columns in the dataset
print(df.columns)

# Identify categorical variables (usually of type 'object' or 'category')
categorical_vars = df.select_dtypes(include=['object', 'category']).columns
print("Categorical Variables:")
print(categorical_vars)

# Identify numerical variables (usually of type 'int64' or 'float64')
numerical_vars = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical Variables:")
print(numerical_vars)
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes', 'product_name'],
#       dtype='object')
# Categorical Variables:
# Index(['review_id', 'product_id', 'title', 'author', 'content', 'timestamp',
#        'profile_id', 'product_attributes', 'product_name'],
#       dtype='object')
# Numerical Variables:
# Index(['rating', 'is_verified', 'helpful_count'], dtype='object')

# %% [markdown]
# 1.   **Nominal Variables** : These variables have categories with no inherent order or ranking:
#
# **product_id**: This identifies different products, but there’s no order among them. Each product is simply a category.
#
# **author**: The name or identifier of the person who wrote the review. There’s no ranking among authors.
#
# **review_id**: Unique identifier for each review. No inherent order or ranking.
#
# **profile_id**: Identifier for the reviewer's profile. No ranking, just a category.
#
# **product_attributes**: Describes product features like color or style. These are typically nominal because there's no natural order among different colors or styles.
#
# **title**: The title of the review. This is text data and treated as nominal if used categorically.
#
# **content**: The body of the review. This is also text data and can be treated as nominal if you are categorizing it in some way.
#
#
#
# 2. **Ordinal Variables**: These variables have categories with a meaningful order:
#
# **rating**: Ratings typically have a natural order (e.g., 1 star < 2 stars < 3 stars, etc.). This makes rating an ordinal variable.

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# ### 5.1 Data Overview
# Provide a summary of the dataset, including key statistics (mean, median, mode, standard deviation, etc.).

# %%
df.describe()
# Out:
#            rating  is_verified  helpful_count
# count  945.000000        945.0     945.000000
# mean     4.478307          1.0       4.600000
# std      0.685662          0.0      24.433818
# min      3.000000          1.0       0.000000
# 25%      4.000000          1.0       0.000000
# 50%      5.000000          1.0       0.000000
# 75%      5.000000          1.0       1.000000
# max      5.000000          1.0     327.000000

# %% [markdown]
# The rating column shows high consistency, with most values between 4 and 5 and a low variation (std of 0.69). The is_verified column is constant at 1, indicating all entries are from verified users. The helpful_count column has a wide range from 0 to 327, with most values close to 0 but some high outliers, resulting in a high standard deviation of 24.43. This suggests that while most entries received few helpful votes, a few entries were marked as very helpful.

# %% [markdown]
# ### 5.2 Visualizations
# Include relevant visualizations (histograms, box plots, scatter plots, etc.) and explain what each visualization reveals about the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6, 3))

# Plot histograms for numerical columns
numerical_columns = ['rating', 'helpful_count']
for i, col in enumerate(numerical_columns):
    plt.subplot(1, len(numerical_columns), i + 1)
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# Box Plot
plt.figure(figsize=(6, 3))

# Plot box plots for numerical columns
for i, col in enumerate(numerical_columns):
    plt.subplot(1, len(numerical_columns), i + 1)
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# Scatter Plot
plt.figure(figsize=(6, 3))

# Scatter plot
sns.scatterplot(x=df['rating'], y=df['helpful_count'])
plt.title('Scatter Plot of Rating vs Helpful Count')
plt.xlabel('Rating')
plt.ylabel('Helpful Count')
plt.show()

# %%
# Initialize variables to store subset means
subset_means = []

# Calculate mean ratings for each subset of 100 rows
for start in range(0, 1000, 100):
    subset_df = df.iloc[start:start + 100]
    mean_rating = subset_df['rating'].mean()
    subset_means.append(mean_rating)

# Create categories for each subset
product_labels = ['HTC Wireless Headphones', 'JBL Tune 230NC TWS',
    'JLab Go Air Pop', 'Beats Studio Buds', 'Jabra Elite 4', 'Sennheiser CX True Wireless',
    'Skullcandy Smokin Buds', 'Sony WF-C700N',
    'Bose SoundLink Flex', 'Beats Pill']
# Create the bar chart
plt.figure(figsize=(9, 5))
plt.bar(product_labels, subset_means)
plt.title('Average Rating for Each Brand of Headphone')
plt.xlabel('Product')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of ratings in this chart reveals high consumer satisfaction across most headphone brands, with average ratings clustered around 4 to 5 stars. Products like the JBL Tune 230NC TWS, Bose SoundLink Flex, Beats Pill, and Sony WF-C700N stand out with near-perfect ratings, indicating strong approval from users. Brands such as JLab Go Air Pop, Beats Studio Buds, Jabra Elite 4, Sennheiser CX True Wireless, and Skullcandy Smokin Buds also show consistently high satisfaction, though with slightly more variation in ratings.
#
# HTC Wireless Headphones have the lowest average rating in this group, suggesting moderate consumer satisfaction and perhaps more diverse user experiences or specific areas for product improvement.
#
# Overall, the distribution suggests that most users are highly satisfied with their headphones, with only minor differences among brands in this selection.

# %%
#Frequencies of each Rating for each Headphone

#HTC Wireless Headphones
subset_df = df.iloc[1:101]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for HTC Wireless Headphones')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#JBL Tune 230ONC TWS
subset_df = df.iloc[101:201]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for JBL Tune 230ONC TWS')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#jlab go Air Pop
subset_df = df.iloc[201:301]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for jlab go Air Pop')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#Beats Studio Buds
subset_df = df.iloc[301:401]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Beats Studio Buds')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#Jabra Elite 4
subset_df = df.iloc[401:501]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Jabra Elite 4')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()


#Sennheiser CX True Wireless
subset_df = df.iloc[501:601]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Sennheiser CX True Wireless')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#Skullcandy Smokin Buds
subset_df = df.iloc[601:701]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Skullcandy Smokin Buds')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#Bose SoundLink Flex
subset_df = df.iloc[701:801]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Bose SoundLink Flex')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

#Sony WF-C700N
subset_df = df.iloc[801:901]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Sony WF-C700N')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()


#Beats pill
subset_df = df.iloc[901:1000]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Beats Pill')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#Beats pill
subset_df = df.iloc[901:1000]
plt.figure(figsize=(4, 4))
plt.hist(subset_df['rating'], bins=10, edgecolor='black')
plt.title('Distribution of Ratings for Beats Pill')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Initialize the list to store data for each subset
subset_ratings = []

# Divide the data into subsets of 100 rows each and calculate rating frequencies
for start in range(0, 1000, 100):
    subset_df = df.iloc[start:start + 100]
    rating_counts = subset_df['rating'].value_counts().sort_index()
    subset_ratings.append(rating_counts)

# Convert the list of rating frequencies to a DataFrame
heatmap_data = pd.DataFrame(subset_ratings).fillna(0).T

# Assign the provided product labels to each subset
product_labels = ['HTC Wireless Headphones', 'JBL Tune 230NC TWS',
    'JLab Go Air Pop', 'Beats Studio Buds', 'Jabra Elite 4', 'Sennheiser CX True Wireless',
    'Skullcandy Smokin Buds', 'Sony WF-C700N',
    'Bose SoundLink Flex', 'Beats Pill']
heatmap_data.columns = product_labels

# Create the heatmap
plt.figure(figsize=(7, 5))
sns.heatmap(heatmap_data, annot=True, cmap='viridis', linewidths=.5)
plt.title('Heatmap of Rating Frequencies of Each Headphone')
plt.xlabel('Product')
plt.ylabel('Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Descriptive Statistics
# Discuss key findings from the descriptive statistics, highlighting any patterns, trends, or anomalies.

# %% [markdown]
# The VADER sentiment analyzer from NLTK was used to perform sentiment analysis on the review titles. Reviews were classified into positive, negative, and neutral categories based on their compound scores. Data was divided into subsets of 100 rows for detailed analysis. Sentiment counts and aggregates for each subset were calculated to summarize overall sentiment. The analysis provided insights into consumer satisfaction for each product.

# %%
# Import the necessary library
import nltk

# Download VADER lexicon
nltk.download('vader_lexicon')

# Initialize the sentiment intensity analyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer  # Corrected import statement
sia = SentimentIntensityAnalyzer()
# Perform sentiment analysis on text reviews
df['sentiment'] = df['title'].apply(lambda x: sia.polarity_scores(x))

# Classify reviews into positive, negative, and neutral
df['sentiment_class'] = df['sentiment'].apply(lambda x: 'positive' if x['compound'] > 0.05 else ('negative' if x['compound'] < -0.05 else 'neutral'))

# Initialize lists to store results for each subset
subset_sentiments = []
subset_aggregates = []

# Divide the data into subsets of 100 rows each
for start in range(0, len(df), 100):
    subset_df = df.iloc[start:start + 100]
    subset_sentiments.append(subset_df['sentiment_class'].value_counts())
    subset_aggregates.append(subset_df['sentiment'].apply(pd.Series).mean())

# Assign the provided product labels to each subset
product_labels = ['HTC Wireless Headphones', 'JBL Tune 230NC TWS',
    'JLab Go Air Pop', 'Beats Studio Buds', 'Jabra Elite 4', 'Sennheiser CX True Wireless',
    'Skullcandy Smokin Buds', 'Sony WF-C700N',
    'Bose SoundLink Flex', 'Beats Pill']

# Create DataFrames for visualization
sentiments_df = pd.DataFrame(subset_sentiments).fillna(0)
sentiments_df.index = product_labels
aggregates_df = pd.DataFrame(subset_aggregates).fillna(0)
aggregates_df.index = product_labels

# Display the sentiment classification counts
print("Sentiment Classification Counts:")
print(sentiments_df)

# Display the sentiment aggregates
print("\nSentiment Aggregates:")
print(aggregates_df)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment Classification Counts:
# sentiment_class              positive  neutral  negative
# HTC Wireless Headphones            65       23        12
# JBL Tune 230NC TWS                 69       26         5
# JLab Go Air Pop                    68       26         6
# Beats Studio Buds                  64       29         7
# Jabra Elite 4                      64       24        12
# Sennheiser CX True Wireless        65       26         9
# Skullcandy Smokin Buds             60       27        13
# Sony WF-C700N                      73       25         2
# Bose SoundLink Flex                71       25         4
# Beats Pill                         36        7         2
#
# Sentiment Aggregates:
#                                   neg       neu      pos  compound
# HTC Wireless Headphones      0.040430  0.743280  0.21631  0.305427
# ...

# %% [markdown]
# ## 6. Sentiment Analysis
#
# ### 6.1 Methodology
# Explain the sentiment analysis techniques used (e.g., TextBlob, NLTK) and provide code snippets.

# %% [markdown]
# The VADER sentiment analyzer from NLTK was used to perform sentiment analysis on the review titles. Reviews were classified into positive, negative, and neutral categories based on their compound scores. Data was divided into subsets of 100 rows for detailed analysis. Sentiment counts and aggregates for each subset were calculated to summarize overall sentiment. The analysis provided insights into consumer satisfaction for each product.

# %%
# Import the necessary library
import nltk

# Download VADER lexicon
nltk.download('vader_lexicon')

# Initialize the sentiment intensity analyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer  # Corrected import statement
sia = SentimentIntensityAnalyzer()
# Perform sentiment analysis on text reviews
df['sentiment'] = df['title'].apply(lambda x: sia.polarity_scores(x))

# Classify reviews into positive, negative, and neutral
df['sentiment_class'] = df['sentiment'].apply(lambda x: 'positive' if x['compound'] > 0.05 else ('negative' if x['compound'] < -0.05 else 'neutral'))

# Initialize lists to store results for each subset
subset_sentiments = []
subset_aggregates = []

# Divide the data into subsets of 100 rows each
for start in range(0, len(df), 100):
    subset_df = df.iloc[start:start + 100]
    subset_sentiments.append(subset_df['sentiment_class'].value_counts())
    subset_aggregates.append(subset_df['sentiment'].apply(pd.Series).mean())

# Assign the provided product labels to each subset
product_labels = ['HTC Wireless Headphones', 'JBL Tune 230NC TWS',
    'JLab Go Air Pop', 'Beats Studio Buds', 'Jabra Elite 4', 'Sennheiser CX True Wireless',
    'Skullcandy Smokin Buds', 'Sony WF-C700N',
    'Bose SoundLink Flex', 'Beats Pill']

# Create DataFrames for visualization
sentiments_df = pd.DataFrame(subset_sentiments).fillna(0)
sentiments_df.index = product_labels
aggregates_df = pd.DataFrame(subset_aggregates).fillna(0)
aggregates_df.index = product_labels

# Display the sentiment classification counts
print("Sentiment Classification Counts:")
print(sentiments_df)

# Display the sentiment aggregates
print("\nSentiment Aggregates:")
print(aggregates_df)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment Classification Counts:
# sentiment_class              positive  neutral  negative
# HTC Wireless Headphones            65       23        12
# JBL Tune 230NC TWS                 69       26         5
# JLab Go Air Pop                    68       26         6
# Beats Studio Buds                  64       29         7
# Jabra Elite 4                      64       24        12
# Sennheiser CX True Wireless        65       26         9
# Skullcandy Smokin Buds             60       27        13
# Sony WF-C700N                      73       25         2
# Bose SoundLink Flex                71       25         4
# Beats Pill                         36        7         2
#
# Sentiment Aggregates:
#                                   neg       neu      pos  compound
# HTC Wireless Headphones      0.040430  0.743280  0.21631  0.305427
# ...

# %% [markdown]
# ### 6.2 Results
# Present the sentiment analysis results, including visualizations of sentiment distribution, and discuss the overall sentiment towards Beats by Dre products.

# %% [markdown]
# Sentiment Classification Counts:
#
# Predominantly Positive Sentiment: The majority of headphones, including Sony WF-C700N (73 positive mentions), Bose SoundLink Flex (71), and JBL Tune 230NC TWS (69), have high positive sentiment counts, indicating strong consumer approval.
# Neutral Sentiment: All products have a notable share of neutral reviews, with HTC Wireless Headphones and JLab Go Air Pop showing a balanced sentiment mix, suggesting some consumers find the products meet basic expectations.
# Negative Sentiment: Products like HTC Wireless Headphones (12 negatives) and Skullcandy Smokin Buds (13) have the highest negative sentiment counts, though these remain low relative to their positive reviews.
# Sentiment Aggregates:
#
# Compound Scores: Beats Pill has the highest compound score (0.4526), indicating overall favorable consumer perception. Other high compound scores include Sony WF-C700N (0.4123) and Bose SoundLink Flex (0.4023), showing positive consumer experiences.
# Positive Scores: Bose SoundLink Flex (0.2803) and Sony WF-C700N (0.2782) are among the highest in positive scores, reflecting consistent consumer satisfaction.
# Negative Scores: Sony WF-C700N and Bose SoundLink Flex have minimal negative scores (around 0.01), highlighting their strong consumer approval.
# Beats Products Analysis:
#
# Beats Studio Buds and Beats Pill show high positive scores and favorable compound scores, with Beats Pill leading in sentiment, suggesting broad consumer satisfaction.
# Beats Solo 4 has more neutral and negative feedback than other Beats products, indicating a mixed consumer experience and potential areas for improvement.

# %%
# Assign the provided product labels to each subset
product_labels = ['HTC Wireless Headphones', 'JBL Tune 230NC TWS',
    'JLab Go Air Pop', 'Beats Studio Buds', 'Jabra Elite 4', 'Sennheiser CX True Wireless',
    'Skullcandy Smokin Buds', 'Sony WF-C700N',
    'Bose SoundLink Flex', 'Beats Pill']

# Create DataFrames for visualization
sentiments_df = pd.DataFrame(subset_sentiments).fillna(0)
sentiments_df.index = product_labels
aggregates_df = pd.DataFrame(subset_aggregates).fillna(0)
aggregates_df.index = product_labels

# Visualization of sentiment classification counts
plt.figure(figsize=(12, 8))
sentiments_df.plot(kind='bar', stacked=True)
plt.title('Sentiment Classification Counts by Product')
plt.xlabel('Product')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Sentiment')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. AI-Generated Insights
#
# ### 7.1 Using Gemini AI
# Briefly explain how Gemini AI was used to extract insights and include any relevant code snippets or explanations.
#
# Gemini AI was utilized to extract comprehensive insights from the review texts. After performing sentiment analysis, the reviews were fed into the Gemini AI model, which was configured using the GenerativeModel API. The model generated detailed summaries and highlighted key points from the reviews. This provided deeper insights into customer feedback, including common themes and specific areas of praise or concern. The insights from Gemini AI helped to enhance the understanding of consumer sentiment and inform strategic decisions for product improvement.

# %% [markdown]
# Below is the code snippet used to set up the chatbot .

# %%
# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key):
  genai.configure(api_key=api_key)
  model = genai.GenerativeModel(
      model_name="gemini-1.5-flash",
      generation_config={
          "temperature": 1,
          "top_p": 0.95,
          "top_k": 64,
          "max_output_tokens": 8192,
          "response_mime_type": "text/plain",
          },   )
  chat_session = model.start_chat(history=[])
  prompt = "Analyze the following reviews and summarize the key points:\n\n" + "\n\n".join(reviews)
  response = chat_session.send_message(prompt)
  return response.text

# Select a subset of reviews for Beats
reviews_beats_studio3 = df['title'].iloc[1:101].tolist()

# Analyze reviews using Gemini AI
reviews = reviews_beats_studio3
# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyDXLspi-2BERGGph6TviAS6YQnbsY2Wy9k"

insights = analyze_reviews(reviews, api_key)
print(insights)
# Out:
# ## Key Points from Earbud Reviews:
#
# **Positives:**
#
# * **Sound quality:**  Many reviewers praise the sound quality, often describing it as "amazing," "good," or "better than expected."
# * **Comfort:** Several reviewers mention the earbuds being comfortable, especially for those with smaller ears.
# * **Size:** The small size is a key selling point for many, with reviewers highlighting its suitability for smaller ear canals.
# * **Noise cancellation:** While not universally praised, some reviewers mention the noise cancellation as being effective.
# * **Price:**  Many reviewers find the earbuds to be a good value for the price.
# * **Battery life:** Some users appreciate the battery life, although some also mention it could be better.
# * **Features:**  Reviewers highlight features such as wind noise cancellation, a comfortable fit for side sleeping, and good customer service.
#
# **Negatives:**
#
# ...

# %% [markdown]
# ### 7.2 Key Insights
# Summarize the key insights generated by Gemini AI, including specific examples of prompts used and the responses received.

# %% [markdown]
# This summary captures both the highlights and challenges of earbud reviews:
#
# Positives:
# Sound Quality: Reviewers frequently describe the sound as "amazing" or "better than expected," which suggests consistent satisfaction with audio performance.
# Comfort & Fit for Smaller Ears: Many users mention the earbuds’ comfort, especially those with smaller ears or narrower ear canals.
# Compact Size: The small size is widely appreciated, as it enhances comfort and fits securely in smaller ears.
# Noise Cancellation: Although not universally praised, some reviewers find the noise cancellation helpful in blocking out unwanted noise.
# Price: The earbuds are often seen as a good value, meeting or exceeding expectations for the cost.
# Battery Life: Many users note adequate battery life, though there are some suggestions for improvement.
# Additional Features: Unique features, such as wind noise cancellation, side-sleep comfort, and responsive customer service, add to the positive experience.
# Negatives:
# Durability: Several users report concerns with the earbuds' lifespan, noting frequent malfunctions or breakdowns.
# Fit Issues: Despite the comfort for some, other users experience issues with earbuds staying in place, especially during movement.
# Noise Cancellation Limitations: Some users feel the noise cancellation could be more effective, showing inconsistency in performance.
# Feature Drawbacks: Reported issues with specific features include video latency, accidental dialing, and a lack of audio confirmation on startup.
# Overall Impression:
# The reviews reflect a mixed experience. Positive attributes like sound quality, comfort, and value stand out, but durability, fit, and noise cancellation limitations are recurring concerns. Both aspects are worth considering before making a purchase.

# %% [markdown]
# ### 7.3 Interpretation
# Discuss how these insights can be interpreted and their relevance to Beats by Dre.

# %% [markdown]
# These insights reveal what consumers prioritize in their earbud experiences, pointing to valuable areas where Beats by Dre can refine or innovate. Here's a breakdown of how these insights can be interpreted and their relevance for Beats by Dre:
#
# 1. Sound Quality
# Interpretation: Sound quality is a primary selling point, with consumers praising clear audio, immersive bass, and balance. Users expect premium sound, especially in the mid- and high-end markets.
# Relevance to Beats: Beats by Dre has long been associated with a bass-heavy sound signature, which appeals to some users but can be polarizing. Emphasizing clarity and balance, while maintaining signature bass, could broaden appeal, particularly among audiophiles who seek high-quality sound beyond just powerful bass.
# 2. Comfort and Fit
# Interpretation: Comfort is a top priority, especially for long listening sessions or active use. Consumers with smaller ears often struggle to find earbuds that fit securely.
# Relevance to Beats: Offering earbuds in various sizes, with ergonomic designs or adjustable tips, could enhance Beats’ appeal across demographics. By emphasizing comfort and secure fit, Beats can strengthen its reputation, especially among users who prioritize comfort in active settings.
# 3. Portability and Size
# Interpretation: Users frequently mention size as a key factor, preferring compact, lightweight earbuds that are easy to carry and suitable for exercise or travel.
# Relevance to Beats: Beats products already cater to an on-the-go lifestyle, but the brand could reinforce this image by highlighting portability in marketing campaigns and refining designs to be even more compact and travel-friendly.
# 4. Noise Cancellation
# Interpretation: Noise cancellation is a widely appreciated feature but also a point of mixed feedback, as it doesn’t meet everyone’s expectations.
# Relevance to Beats: Investing in adaptive or customizable noise cancellation can cater to different preferences. Integrating features that allow users to control the level of noise cancellation, such as transparency or “focus” modes, would make Beats more versatile in different environments.
# 5. Durability and Build Quality
# Interpretation: Durability is a consistent concern, with some users experiencing breakdowns or malfunctions.
# Relevance to Beats: By emphasizing robust materials and testing for long-term use, Beats can differentiate itself as a reliable choice, particularly important in the premium market. Offering extended warranties or repair options could also instill confidence.
# 6. Battery Life
# Interpretation: Battery longevity is a highly valued feature, as users want extended usage without frequent recharging.
# Relevance to Beats: Battery life and fast-charging capabilities should be focal points for Beats, especially as users increasingly prioritize headphones that can handle day-to-day use without interruption. Promoting these attributes would align with consumer needs, particularly among active or commuting users.
# 7. Value for Money
# Interpretation: Consumers want features and quality that match the price they’re paying.
# Relevance to Beats: As a premium brand, Beats must justify its price point by providing a standout experience. Features like customizable audio profiles, seamless device integration, and enhanced durability can emphasize that Beats is not only stylish but also packed with advanced capabilities that justify the investment.
# 8. Distinctive Features and Innovation
# Interpretation: Standout features such as good customer service, customizable sound, and unique controls can set products apart.
# Relevance to Beats: By enhancing features that focus on user experience, such as easy device connectivity, touch controls, and proactive customer service, Beats can deepen customer loyalty. Adding innovative elements like wind noise reduction or multipoint Bluetooth (connecting to multiple devices) would further distinguish Beats from competitors.
# Overall Relevance for Beats by Dre:
#
# Beats is already known for a stylish design and strong bass, but these insights suggest additional areas for growth and improvement. By addressing comfort, fit, durability, and battery life — and emphasizing the unique sound profile that Beats users appreciate — the brand can meet a wider range of consumer preferences. This approach not only retains its current customer base but also attracts new segments, reinforcing Beats by Dre’s position as a leader in both style and substance in the premium audio market.

# %% [markdown]
# ## 8. Comparative Analysis
#
# ### 8.1 Competitor Overview
# List the competitors analyzed and provide a brief overview of their market positioning.

# %% [markdown]
#  Here’s a brief overview of the market positioning for each of these specific competitors:
#
# HTC Wireless Headphones
#
# Positioning: HTC’s headphones are positioned as budget-friendly options with a focus on value for money. HTC leverages its reputation in consumer electronics, offering wireless headphones that appeal to entry-level users or those looking for basic functionality at an affordable price.
#
# JBL Tune 230NC TWS
#
# Positioning: Positioned as mid-range true wireless earbuds, the JBL Tune 230NC TWS emphasizes bass-heavy sound and noise cancellation. JBL’s brand is widely recognized for its accessible pricing and quality, catering to younger, active users who want reliable, portable audio options.
#
# JLab Go Air Pop
#
# Positioning: These budget-friendly earbuds are marketed for their affordability and decent audio quality. JLab’s Go Air Pop appeals to budget-conscious consumers and casual listeners who need wireless audio for everyday use without a premium price tag.
#
# Beats Studio Buds
#
# Positioning: The Beats Studio Buds are positioned as mid-range to premium true wireless earbuds within the Beats lineup, appealing to a younger audience with a love for bass-heavy sound. They focus on delivering good sound quality, brand prestige, and an attractive design, along with active noise cancellation.
#
# Jabra Elite 4
#
# Positioning: The Jabra Elite 4 targets the mid-range market with a balance between performance and durability. Known for quality sound and a secure fit, Jabra’s Elite series is popular among active users and professionals who prioritize durability and functional features for exercise or daily wear.
#
# Sennheiser CX True Wireless
#
# Positioning: Positioned as mid-range audiophile-quality earbuds, Sennheiser’s CX series emphasizes sound clarity and a balanced audio profile. Sennheiser appeals to discerning listeners seeking high fidelity without the premium price tag of the Momentum series.
#
# Skullcandy Smokin Buds
#
# Positioning: Skullcandy’s Smokin Buds cater to younger consumers, with a focus on affordability, bold designs, and strong bass. The brand’s reputation for offering fun, affordable audio products makes it attractive to teens and young adults looking for style and sound quality on a budget.
#
# Sony WF-C700N
#
# Positioning: Sony’s WF-C700N targets users seeking high-quality noise cancellation in a mid-range product. Known for its audio and ANC technology, Sony attracts users who value performance and reliability without the higher price of Sony’s flagship models.
#
# Bose SoundLink Flex
#
# Positioning: Positioned as a high-quality, portable Bluetooth speaker, the Bose SoundLink Flex targets consumers who prioritize audio quality, portability, and durability. Bose’s reputation for excellent sound makes it appealing to users who want a reliable on-the-go speaker for various environments.
#
# Beats Pill
#
# Positioning: The Beats Pill is a portable speaker designed for brand-conscious users who value style alongside audio quality. With its trendy design and portable form factor, the Beats Pill appeals to younger users and those looking for a fashionable, easy-to-use Bluetooth speaker for casual listening.
#
# Positioning Implications for Beats by Dre
# Each of these products represents different segments within the consumer audio market, from entry-level to premium quality. Beats by Dre’s Studio Buds and Pill, for example, are positioned to leverage Beats' strong brand identity and appeal to younger, style-conscious users who prioritize bass-heavy sound and aesthetics. By understanding these competitors’ positions, Beats can further differentiate its products, emphasizing unique features and user experiences that align with its brand image.

# %% [markdown]
# ### 8.2 Comparison of Sentiments
# Compare the sentiment analysis results of Beats by Dre with its competitors using visualizations to highlight differences and similarities.

# %% [markdown]
# Beats by Dre is praised for its bass-heavy sound and stylish design, appealing to younger audiences like JBL and Skullcandy. However, Sony and Bose outshine Beats in noise cancellation and durability, catering to more professional users. Comfort is generally positive, though models like Beats Solo 4 received mixed feedback on fit. Beats offers good value but faces competition in feature reliability, where Sony and Jabra excel. Improving durability and functionality would help Beats compete more directly with high-end brands.

# %% [markdown]
# ### 8.3 SWOT Analysis
# Conduct a SWOT analysis (Strengths, Weaknesses, Opportunities, Threats) for Beats by Dre based on the comparative data.

# %% [markdown]
# Here’s a SWOT analysis for Beats by Dre based on the comparative sentiment analysis:
#
# Strengths
# Brand Recognition and Style: Beats by Dre is known for its trendy, youth-oriented design and is a recognizable brand with strong appeal, especially among younger audiences.
# Bass-Heavy Sound Quality: Beats products are appreciated for their powerful bass, catering well to genres like hip-hop and electronic music, which appeals to a specific consumer base.
# Comfort and Fit in Select Models: Models like Beats Studio Pro receive favorable reviews for comfort, making them popular for long listening sessions.
#
# Weaknesses
# Durability Issues: Compared to competitors like Sony and Bose, Beats headphones and earbuds have more frequent complaints about durability, with users reporting breakdowns and malfunctions.
# Noise Cancellation Limitations: While some Beats models offer noise cancellation, it is often rated as less effective than that of competitors like Bose, which specializes in this feature.
# Mixed Fit Feedback: Some models, such as the Beats Solo 4, receive mixed reviews regarding fit, with users finding them either too snug or uncomfortable for extended wear.
#
# Opportunities
# Improving Durability: Addressing durability issues would allow Beats to compete more directly with premium brands, enhancing consumer confidence.
# Expanding Feature Set: Features like advanced noise cancellation, water resistance, and adaptive sound profiles could attract a wider audience, including professional users who seek high-functionality products.
# Targeted Marketing for Active Users: Beats could expand its market by focusing on the active and fitness-oriented demographic, developing models designed for workout comfort and stability.
#
# Threats
# Intense Competition: Competitors like Sony, Bose, JBL, and Jabra have well-established reputations for sound quality, noise cancellation, and durability, which could sway consumers away from Beats.
# Evolving Consumer Expectations: As consumers increasingly expect advanced features and durability, Beats risks losing market share if it fails to keep pace with evolving technology.
# Market Saturation: The audio industry is crowded, with many brands competing in the same price range, meaning consumers have ample choices that may better meet their specific needs.
# By addressing these weaknesses and leveraging opportunities, Beats by Dre could improve its position in the competitive audio market.

# %% [markdown]
# ## 9. Strategic Recommendations
#
# ### 9.1 Product Improvements
# Based on the analysis, suggest specific product improvements.

# %% [markdown]
# . Enhanced Sound Quality
# Bass and Clarity Balance: Fine-tune the audio profile to provide a richer, deeper bass response without compromising mid and high frequencies, which will appeal to listeners who desire a full-range sound.
# Customizable EQ Settings: Allow users to personalize their sound experience by providing adjustable EQ settings through a companion app, enabling them to modify bass, treble, and mids according to their preferences.
# 2. Improved Durability and Build Quality
# Rugged Exterior: Strengthen the exterior casing to make it more resistant to drops, dust, and minor water exposure. This will make the Beats Pill more suitable for outdoor and on-the-go use.
# Enhanced Port Protection: Ensure the ports are well-protected and reinforced to prevent damage from frequent plugging and unplugging.
# 3. Extended Battery Life and Fast Charging
# Increased Battery Capacity: Improve battery life to allow for longer playback time on a single charge, addressing feedback about limited battery duration during extended usage.
# Fast-Charging Capability: Implement fast-charging technology so that users can quickly recharge the device, achieving a significant battery boost in a short amount of time.
# 4. Better Connectivity and Multi-Device Support
# Enhanced Bluetooth Range and Stability: Improve Bluetooth performance to provide a more stable and extended range, minimizing dropouts and ensuring consistent playback quality.
# Seamless Multi-Device Connection: Allow the Beats Pill to connect seamlessly with multiple devices, enabling easy switching between devices without the need for re-pairing.
# 5. User-Friendly Controls and Visual Feedback
# Improved Button Layout: Rework the button design and placement for easier access to volume and playback controls, making the Beats Pill more user-friendly.
# LED Indicators: Add more precise LED indicators for battery life, Bluetooth connectivity, and charging status to give users better visual feedback on the device’s status.
# 6. Accurate Product Descriptions and Marketing
# Realistic Color and Feature Representation: Ensure that the color options and product features advertised are accurate, helping to meet user expectations. This could involve updated product photography and clearer descriptions on packaging and online listings.
# 7. Water and Dust Resistance
# IP Rating Certification: Make the Beats Pill water and dust resistant (ideally with an IPX4 or higher rating), which would allow users to confidently use it in diverse settings, such as outdoor gatherings and gym environments.
# 8. Enhanced Portability and Accessories
# Protective Carry Case: Provide a protective carry case as an optional accessory or bundle item to help protect the Beats Pill during travel.
# Attachable Strap or Handle: Add a secure strap or handle to the design for easy portability, catering to users who frequently carry their Beats Pill with them.
# By implementing these targeted improvements, the Beats Pill could better meet user expectations and compete more effectively in the portable speaker market.

# %% [markdown]
# ### 9.2 Marketing Strategies
# Provide recommendations for marketing strategies that could enhance consumer perception and satisfaction.

# %% [markdown]
# To enhance consumer perception and satisfaction, Beats by Dre should focus on showcasing their product strengths while addressing any weaknesses. Emphasize superior sound quality and portability in marketing materials, and use customer testimonials to highlight these features.
#
# Communicate transparently about recent improvements to volume, bass, and durability issues, and feature positive changes prominently in ads. Running limited-time offers and bundles can attract new customers and incentivize upgrades. Expanding digital presence through social media campaigns and engaging with influencers will boost brand visibility and reach.
#
# Additionally, promoting advanced features like voice assistants and improved connectivity will attract tech-savvy consumers. Engaging with communities through sponsorships and interactive content can strengthen brand connections. Providing educational content on product use and maintenance will help users get the most out of their purchase. Finally, emphasizing excellent after-sales support and easy access to customer service will build trust and loyalty among consumers.
#
# Partnerships: Collaborate with tech reviewers, musicians, lifestyle bloggers, and celebrities who align with the brand's image. Encourage them to share honest reviews and unboxings.

# %% [markdown]
# ### 9.3 Future Research
# Suggest areas for future research or additional data that could be collected to further enhance the analysis.

# %% [markdown]
# 1. In-Depth Customer Demographics Analysis
#
# Focus Groups: Collect and analyze feedback from specific customers to understand varying preferences and tailor products and marketing strategies accordingly.
# Purchasing Behavior: Study purchasing patterns to identify peak buying times and popular models among different demographics.
# 2. Study Competition
#
# Feature Comparison: Perform a detailed comparison of key features (e.g., battery life, sound quality, durability) across competitors to identify gaps and opportunities for improvement.
# Price Sensitivity Analysis: Examine how price changes affect sales and compare with competitors' pricing strategies.
# 3. Environmental and Social Impact
#
# Sustainability Initiatives: Research the environmental impact of Beats products and explore opportunities for using sustainable materials and practices.
#
# 4. Marketing Campaign Impact: Assess the effectiveness of different marketing strategies by analyzing metrics like engagement and sales to determine what works best.

# %% [markdown]
# ## 10. Conclusion
# Summarize the key findings and their implications, and reflect on the overall project and its contribution to understanding consumer sentiment for Beats by Dre.

# %% [markdown]
# Key Findings and Implications Positive Sentiment Dominates: Customers overwhelmingly appreciate the Beats speaker for its sound quality, portability, and value for money. This highlights the brand's strong position in these areas but also points to the need for continued excellence in these aspects to maintain consumer satisfaction.
#
# Areas for Improvement: While the overall reception is positive, there are concerns about volume limitations, bass quality, durability, and battery life. Addressing these issues could enhance the product's appeal and reduce negative feedback.
#
# Competitive Position: Beats stands strong in sound quality and design compared to competitors but needs to address similar issues seen in rival products, such as battery life and durability, to stay competitive.
#
# Consumer Feedback Utilization: Leveraging detailed customer feedback and reviewing long-term user experiences can provide deeper insights into product performance and areas needing improvement.
#
# Marketing Strategies: Effective marketing strategies should highlight the speaker's strengths and communicate improvements transparently. Exploring advanced features and enhancing after-sales support can further bolster consumer satisfaction.
#
# Reflection on the Overall Project The project provides valuable insights into consumer sentiment for Beats by Dre, emphasizing the importance of addressing product weaknesses while capitalizing on strengths. By understanding consumer feedback and market trends, the analysis helps identify actionable improvements and strategic opportunities. This comprehensive approach not only enhances product development and marketing strategies but also contributes to a better understanding of how consumer preferences shape the success of consumer electronics. The findings and recommendations can guide Beats in refining their product and marketing efforts, ultimately fostering greater consumer satisfaction and brand loyalty.

# %% [markdown]
# ## 11. References
# List all the sources, tools, and references used in the project.

# %% [markdown]
# Reference:
#
# https://www.youtube.com/watch?v=pTcunloZ-_o
#
# https://www.nltk.org/howto/sentiment.html
# Extern Platform
# OxyLabs API
# Gemini AI
# Google Collab
# Python
